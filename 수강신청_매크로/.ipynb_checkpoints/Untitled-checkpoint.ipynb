# %%
from bs4 import BeautifulSoup as bs

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import chromedriver_autoinstaller

import time

# %%
# Chrome driver Auto-install
driver_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(driver_path)
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_7852\2031976854.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)

# %%
with open('information.txt', 'r') as f:
    id = f.readline().replace('\n', '')
    pw = f.readline()

# %%
driver.get('https://sugang.skhu.ac.kr/')

# %%
driver.switch_to.frame('Main')

login_id = driver.find_element(By.ID, 'txtUserID')
login_pw = driver.find_element(By.ID, 'txtPwd')
login_bt = driver.find_element(By.ID, 'btn-login')

login_id.send_keys(id)
login_pw.send_keys(pw)

# %%
login_bt.click()

# %%
time.sleep(1)
driver.execute_script("fnMenuLoad('/core/coreNotice1')")

# %%
# page_scr = driver.page_source
# soup = bs(page_scr, 'lxml')

# %%
# bt = soup.find('button', attrs={'class': 'btn-lg'})
# bt

# %%
start_bt = driver.find_element(By.CLASS_NAME, 'btnStart')
time.sleep(1)
start_bt.click()

# %%
print(driver.page_source)
# Out:
# <html lang="ko"><head>
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta charset="UTF-8">
# <meta name="viewport" content="user-scalable=no, initial-scale=1, maximum-scale=1, minimum-scale=1, width=device-width, viewport-fit=cover">
# <meta content="date=no" name="format-detection">
# <meta content="telephone=no" name="format-detection">
# <meta content="address=no" name="format-detection">
# <title>성공회대학교 수강신청시스템</title>
# <link href="/resources/css/ui.css" rel="stylesheet" type="text/css">
# <link href="/resources/css/jqgrid.css" rel="stylesheet" type="text/css">
# <style>
# /* @media (min-width: 1000px)
# body.main>header .is-right .user-info {
#     width: 320px;
# }
# @media (min-width: 1000px)
# body.main>header .is-right .user-info button {
#     margin: auto;
# } */
# @media (min-width: 1000px)
# body.main>header .is-right .user-info button {
#     margin-top: 0px;
# }
# </style>
# <link rel="shortcut icon" href="/resources/img/favicon.ico" type="image/x-icon">
# <link rel="icon" href="/resources/img/favicon.ico" type="image/x-icon">
# <script src="/resources/js/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/resources/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/resources/js/jquery.jqGrid.min.js" type="text/javascript"></script>
# <script src="/resources/js/confirm.js" type="text/javascript"></script>
# <script src="/resources/js/project-ui.js?v=" type="text/javascript"></script>
# <script src="/resources/js/app-message.js" type="text/javascript"></script>
# <script type="text/javascript">
# var context = "";
# $(function() {
#
# 	//메뉴 제어
# 	$(".nav-menu  > li > span").each(function(){
# 		var $sub = $(this).next("div");
# 		$(this).click(function(){
# 			if($(this).hasClass("is-active")){
# 				$(this).removeClass("is-active");
# 				$sub.slideUp("fast");
# 			}
# 			else{
# 				$(".nav-menu  > li > span").removeClass("is-active");
# 				$(".nav-menu  > li > div").hide();//.slideUp("fast");
# 				$(this).addClass("is-active");
# 				$sub.slideDown("fast");
# 			}
# 		});
# 	});
# 	$(".m-menu").click(function(){
# 		$(".wrap-header .is-right").slideToggle();
# 	});
# 	$(window).bind('resize', function() {
# 		if($(".m-menu").css("display") == "block"){
# 			$(".wrap-header .is-right").hide();
# 		}else{
# 			$(".wrap-header .is-right").show();
# 		}
# 	});
# 	$(document).click(function(e) {
# 		if($(".m-menu").css("display") == "block"){
# 			if ($(e.target).closest(".m-menu, .wrap-header .is-right").length === 0) {
# 				$(".wrap-header .is-right").hide();
# 			}
# 		}
# 		 if($(".nav-menu > li > span").hasClass("is-active")){
# 			if($(e.target).closest(".nav-menu").length === 0){
# 				$(".nav-menu  > li > span").removeClass("is-active");
# 				$(".nav-menu  > li > div").hide();
# 			}
# 		}
# 	});
#
# 	//Top 버튼
# 	$('.to-top').click(function(){
# 		$("html, body").animate({scrollTop : 0},500);
# 		return false;
# 	});
# 	$(window).scroll(function() {
# 		//Top 버튼
# 		if ($(this).scrollTop() > 100) {
# 			$('.to-top').fadeIn("fast");
# 		} else {
# 			$('.to-top').fadeOut("fast");
# 		}
# 	});
# 	const menu = JSON.parse(localStorage.getItem('menu'));
# 	let menuUrl;
# 	if(menu == null){
# 		menuUrl	= "/core/schedule";
# 	}else{
# 		menuUrl = menu.menuUrl;
# 	}
# 	fnMenuLoad(menuUrl);
# 	try{
# 		if(parent.fnAppUsed() == false){
# 			top.location.href = "about:blank";
# 		}
# 	}catch(err){
# 		top.location.href = "about:blank";
# 	}
# });
# function logout(msg){
# 	if(msg == undefined){
# 		fnLogout(fnGetMessage(2), goLogout, '', true);
# 	}else{
# 		fnLogout(msg, goLogout);
# 	}
# }
# function goLogout(){
# 	localStorage.clear();
# 	location.href= context + "/logOut?fake=" + Date.now();
# }
# function fnMenuLoad(menuUrl){
# 	try{extendTimer();}catch(err){}
# 	localStorage.setItem('menu',JSON.stringify({'menuUrl': menuUrl}));
# 	$(".nav-menu  > li > span").removeClass("is-active");
# 	$(".nav-menu  > li > div").hide();
# 	if($(".m-menu").css("display") == "block"){
# 		$(".wrap-header .is-right").hide();
# 	}
# 	$(".s-contents > div").empty();
# 	let queryStr = (menuUrl.indexOf("?")>-1 ? "&":"?") + "fake="+Date.now();
# 	$(".s-contents > div").load(context + menuUrl + queryStr, function(response, status, xhr) {
# 		if(status == "success"){
# 			var rs, code, msg;
# 			try{
# 				rs = $.parseJSON(response);
# 			}catch(err){}
# 			if(rs == undefined){
# 				code = "200";
# 				msg  = "OK";
# 			}else{
# 				code = rs.code || rs.rows[0].code;
# 				msg = rs.msg || rs.rows[0].msg;
# 			}
# 			if(code == "999"){
# 				$(".s-contents > div").hide();
# 				logout(msg);
# 			}else if(code == "DB" || code != "200"){
# 				$(".s-contents > div").empty();
# 				fnAlert(msg);
# 			}
# 		}else{
# 			var chk = function(){
# 				setTimeout(function(){
# 					location.reload();
# 				},500);
# 			}
# 		}
# 	});
# }
# function gridCheck(data, grid){
# 	 try{
# 		var code = data.code || data.rows[0].code;
# 		var msg = data.msg || data.rows[0].msg;
# 		if(code == "999"){
# 			logout(msg);
# 			return false;
# 		}else if(code == "500"){
# 			setNodata(grid, msg);
# 			return false;
# 		}
# 	}catch(err){
# 		return true;
# 	}
# 	return true;
# }
# function fnHome(){
# 	localStorage.clear();
# 	parent.location.href = context + "/";
# }
# </script>
# <style>
# .main-menu{cursor:pointer;}
# .tbl-detail, .wrap-grid{min-width:600px;}
# </style>
# </head>
# <body class="main">
# 	<div class="wrap-loader hidden" style="display: none;"><span class="loading-helper"></span><div class="loader"></div><div class="loading-text">Loading</div></div>
# 	<span class="to-top" style="display: inline-block;"></span>
# 	<header>
# 		<div class="wrap-header">
# 			<div class="is-left" onclick="fnHome()" style="cursor:pointer;" title="홈(Home)">
# 				<span>수강신청</span>
# 			</div>
# 			<div class="is-right" style="display: none;">
# 				<ul class="nav-menu">
# 					<li>
# 						<span class="main-menu">수강신청</span>
# 						<div style="display: none;">
# 							<ul>
# 								<li onclick="fnMenuLoad('/core/coreNotice1')">신청</li>
# 								<li onclick="fnMenuLoad('/sugang/sugangSelect')">결과조회</li>
# 							</ul>
# 						</div>
# 					</li>
#
# 					<li>
# 						<span class="main-menu">수강바구니</span>
# 						<div style="display: none;">
# 							<ul>
# 								<li onclick="fnMenuLoad('/core/coreNotice2')">신청</li>
# 								<li onclick="fnMenuLoad('/basket/basketSelect')">결과조회</li>
# 							</ul>
# 						</div>
# 					</li>
#
# 					<li>
# 						<span class="main-menu">제한수업</span>
# 						<div style="display: none;">
# 							<ul>
# 								<li onclick="fnMenuLoad('/core/coreNotice3')">신청</li>
# 								<li onclick="fnMenuLoad('/sugang/limitSelect')">결과조회</li>
# 							</ul>
# 						</div>
# 					</li>
# 					<li>
# 						<span class="main-menu">대체과목 재수강</span>
# 						<div style="display: none;">
# 							<ul>
# 								<li onclick="fnMenuLoad('/core/coreValid?pScheGb=0214')">신청</li>
# 								<!-- <li onclick="fnMenuLoad('/core/coreNotice5')">신청</li> -->
# 							</ul>
# 						</div>
# 					</li>
#
# 					<li>
# 						<span class="main-menu">수강철회</span>
# 						<div style="display: none;">
# 							<ul>
# 								<li onclick="fnMenuLoad('/core/coreNotice4')">신청</li>
# 								<li onclick="fnMenuLoad('/sugang/withdrawSelect')">결과조회</li>
# 							</ul>
# 						</div>
# 					</li>
# 				</ul>
# 				<div class="user-info">
#
# 					<div><span class="is-id">201814102</span><span>박결</span><br>
# 					<span>공학계 IT융합자율학부</span>
#
# 					<span>4학년</span>
#
# 					</div>
# 					<button type="button" class="btn-sub" id="btn" onclick="logout()">로그아웃</button>
# 				</div>
# 			</div>
# 			<div class="m-menu"></div>
# 		</div>
# 	</header>
# 	<main class="s-contents" id="s-contents"><div>
#
#
#
#
# <h1 class="is-title">2023년 1학기 재학생 수강신청</h1>
#
#
# <div class="sw-header">
# 	<h1>기본정보</h1>
# </div>
# <div class="wrap-content">
# 	<table class="tbl-detail">
# 		<colgroup>
# 			<col width="90px">
# 			<col>
# 			<col width="90px">
# 			<col>
# 			<col width="90px">
# 			<col>
# 		</colgroup>
# 		<tbody>
# 			<tr>
# 				<th>학번</th>
# 				<td>201814102</td>
# 				<th>성명</th>
# 				<td>박결</td>
# 				<th>학적상태</th>
# 				<td>재학</td>
# 			</tr>
#
# 			<tr>
# 				<th>소속</th>
# 				<td>IT융합자율학부</td>
# 				<th>학년이수학기</th>
# 				<td>4학년(9학기)</td>
# 				<th>과정구분</th>
# 				<td>학부과정</td>
# 			</tr>
# 			<tr>
# 				<th>신청전공</th>
# 				<td colspan="5">IT융합자율학부<br>(주전공) 소프트웨어공학전공<br>(부전공) 컴퓨터공학전공</td>
# 			</tr>
#
#
# 		</tbody>
# 	</table>
# </div>
# <div class="sw-header mt-20">
# 	<h1>학점정보</h1>
# </div>
# <div class="wrap-content">
# 	<table class="tbl-detail">
# 		<colgroup>
# 			<col width="10%">
# 			<col width="10%">
# 			<col width="10%">
# 			<col width="20%">
# 			<col width="10%">
# 			<col width="20%">
# 		</colgroup>
# 		<thead>
# 			<tr>
# 				<th>직전학기 평점/취득</th>
# 				<th>학점세이브</th>
# 				<th>선신청 학점</th>
# 				<th>신청가능 학점</th>
# 				<th>신청학점</th>
# 				<th>수강 예정 학점</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 			<tr>
# 				<td class="alignC">2.33 / 142</td>
# 				<td class="alignC">0</td>
# 				<td class="alignC">0</td>
# 				<td class="alignC"><span style="font-size:11px">(기본 + 성적우수 +<br>
# 									학점세이브 - 선신청)=신청가능</span><br>
# 									<b>(19 + 0 + 0 - 0) = 19</b></td>
# 				<td class="alignC"><span id="PNT_SUM">3</span></td>
# 				<td class="alignC"><span style="font-size:11px">(기존 총취득 학점 + 선신청학점 +<br>
# 									신청학점)=총 취득 예상 학점</span><br>
# 									<b id="PNT_TOT">(142 + 0 + 3) = 145</b></td>
# 			</tr>
# 		</tbody>
# 	</table>
# </div>
# <div class="sw-header mt-20">
# 	<h1>수강신청 내역 <small>【 신청과목수 : <span style="color: #f76700;" id="CNT">1</span>건 】</small></h1>
# </div>
# <div class="wrap-content">
# 	<div class="wrap-grid"><div class="ui-jqgrid ui-widget ui-widget-content ui-corner-all" id="gbox_GridSugang" dir="ltr" style="width: 795px;"><div class="ui-widget-overlay jqgrid-overlay" id="lui_GridSugang"></div><div class="loading ui-state-default ui-state-active" id="load_GridSugang" style="display: none;">Loading ...</div><div class="ui-jqgrid-view" role="grid" id="gview_GridSugang" style="width: 795px;"><div class="ui-jqgrid-titlebar ui-jqgrid-caption ui-widget-header ui-corner-top ui-helper-clearfix" style="display: none;"><a role="link" class="ui-jqgrid-titlebar-close ui-corner-all HeaderButton" style="right: 0px;"><span class="ui-icon ui-icon-circle-triangle-n"></span></a><span class="ui-jqgrid-title"></span></div><div class="ui-state-default ui-jqgrid-hdiv ui-corner-top" style="width: 795px;"><div class="ui-jqgrid-hbox"><table class="ui-jqgrid-htable ui-common-table" style="width: 795px;" role="presentation" aria-labelledby="gbox_GridSugang"><thead><tr class="ui-jqgrid-labels" role="row"><th id="GridSugang_mode" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 62px;"><div id="jqgh_GridSugang_mode" class="ui-jqgrid-sortable">삭제<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridSugang_lec_info" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 164px;"><div id="jqgh_GridSugang_lec_info" class="ui-jqgrid-sortable">과목정보<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridSugang_map_mj" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 103px;"><div id="jqgh_GridSugang_map_mj" class="ui-jqgrid-sortable">전공/이수구분<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridSugang_pnt" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 31px;"><div id="jqgh_GridSugang_pnt" class="ui-jqgrid-sortable">학점<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridSugang_pesn_nm" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 62px;"><div id="jqgh_GridSugang_pesn_nm" class="ui-jqgrid-sortable">대표교수<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridSugang_ability" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 62px;"><div id="jqgh_GridSugang_ability" class="ui-jqgrid-sortable">핵심역량<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridSugang_ability_detail" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" ...
# </div>
#
# <ul class="sw-tabs mt-20" id="sTabs">
# 	<li data-id="tab_01" class="is-active">수강바구니 조회/신청</li>
# 	<li data-id="tab_02">개설과목 조회/신청</li>
# </ul>
# <div class="sw-tab-contents" id="tab">
# 	<div id="tab_01" class="is-active">
# 		<div class="wrap-content">
# 			<div class="wrap-grid"><div class="ui-jqgrid ui-widget ui-widget-content ui-corner-all" id="gbox_GridBasket" dir="ltr" style="width: 795px;"><div class="ui-widget-overlay jqgrid-overlay" id="lui_GridBasket"></div><div class="loading ui-state-default ui-state-active" id="load_GridBasket" style="display: none;">Loading ...</div><div class="ui-jqgrid-view" role="grid" id="gview_GridBasket" style="width: 795px;"><div class="ui-jqgrid-titlebar ui-jqgrid-caption ui-widget-header ui-corner-top ui-helper-clearfix" style="display: none;"><a role="link" class="ui-jqgrid-titlebar-close ui-corner-all HeaderButton" style="right: 0px;"><span class="ui-icon ui-icon-circle-triangle-n"></span></a><span class="ui-jqgrid-title"></span></div><div class="ui-state-default ui-jqgrid-hdiv ui-corner-top" style="width: 795px;"><div class="ui-jqgrid-hbox"><table class="ui-jqgrid-htable ui-common-table" style="width: 795px;" role="presentation" aria-labelledby="gbox_GridBasket"><thead><tr class="ui-jqgrid-labels" role="row"><th id="GridBasket_mode" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 62px;"><div id="jqgh_GridBasket_mode" class="ui-jqgrid-sortable">신청<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridBasket_lec_info" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 164px;"><div id="jqgh_GridBasket_lec_info" class="ui-jqgrid-sortable">과목정보<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridBasket_map_mj" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 103px;"><div id="jqgh_GridBasket_map_mj" class="ui-jqgrid-sortable">전공/이수구분<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridBasket_pnt" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 31px;"><div id="jqgh_GridBasket_pnt" class="ui-jqgrid-sortable">학점<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridBasket_pesn_nm" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 62px;"><div id="jqgh_GridBasket_pesn_nm" class="ui-jqgrid-sortable">대표교수<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridBasket_ability" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 62px;"><div id="jqgh_GridBasket_ability" class="ui-jqgrid-sortable">핵심역량<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridBasket_ability_detail" role="columnheader" class="ui-state-default ui-th-column ui-th-lt ...
# 		</div>
# 	</div>
# 	<div id="tab_02">
# 		<div class="info-box">
# 			<p>① 조회조건을 1개이상 설정 후 조회 가능합니다.</p>
# 			<p>② 과목 옆에 표시되는 전공/이수구분은 성적취득 시 실제로 취득되는 전공정보와 이수구분이 나타납니다.</p>
# 			<p>③ 전필, 전선, 전탐의 경우 본인의 신청전공 및 수업학년에 해당하는 과목만 조회가능합니다.</p>
# 		</div>
# 		<form name="sForm" id="sForm" method="post" onsubmit="return false">
# 		<div class="form-search">
# 		<div>
# 			<div>
# 				<select name="pSosocCd" id="pSosocCd">
# 		        	<option value="">전체</option>
#
# 				        <option value="U080000">학부 열림교양대학</option>
#
# 				        <option value="UCE0000">혁신융합계열 국제문화전공</option>
#
# 				        <option value="UD00000">사회계 미디어콘텐츠융합자율학부</option>
#
# 				        <option value="UDA0000">미디어콘텐츠융합자율학부 디지털콘텐츠전공</option>
#
# 				        <option value="UDB0000">미디어콘텐츠융합자율학부 신문방송학전공</option>
#
# 				        <option value="UH00000">인문계 인문융합자율학부</option>
#
# 				        <option value="UHB0000">인문융합자율학부 기독교문화전공</option>
#
# 				        <option value="UHC0000">인문융합자율학부 영어학전공</option>
#
# 				        <option value="UHD0000">인문융합자율학부 일어일본학전공</option>
#
# 				        <option value="UHE0000">인문융합자율학부 중어중국학전공</option>
#
# 				        <option value="UI00000">공학계 IT융합자율학부</option>
#
# 				        <option value="UIB0000">IT융합자율학부 컴퓨터공학전공</option>
#
# 				        <option value="UIC0000">IT융합자율학부 소프트웨어공학전공</option>
#
# 				        <option value="UID0000">IT융합자율학부 정보통신공학전공</option>
#
# 				        <option value="UIF0000">IT융합자율학부 인공지능전공</option>
#
# 				        <option value="US00000">사회계 사회융합자율학부</option>
#
# 				        <option value="USB0000">사회융합자율학부 사회복지학전공</option>
#
# 				        <option value="USC0000">사회융합자율학부 사회학전공</option>
#
# 				        <option value="USD0000">사회융합자율학부 경제학전공</option>
#
# 				        <option value="USE0000">사회융합자율학부 정치학전공</option>
#
# 				        <option value="USH0000">사회융합자율학부 경영학전공</option>
#
# 		        </select>
# 				<label class="is-label">과목명/과목코드/교원명</label>
# 				<input type="text" name="pSearchNm" id="pSearchNm" maxlength="30">
# 			</div>
# 			<div class="is-full">
# 				<label class="is-label">이수구분</label>
# 				<input type="checkbox" name="pIsuGb" value="D0221" id="chk1_01"><label for="chk1_01">전필</label>
# 				<input type="checkbox" name="pIsuGb" value="D0222" id="chk1_02"><label for="chk1_02">전선</label>
# 				<input type="checkbox" name="pIsuGb" value="D0223" id="chk1_03"><label for="chk1_03">전탐</label>
# 				<input type="checkbox" name="pIsuGb" value="D0210" id="chk1_04"><label for="chk1_04">교필</label>
# 				<input type="checkbox" name="pIsuGb" value="D0213" id="chk1_05"><label for="chk1_05">교선</label>
# 				<input type="checkbox" name="pIsuGb" value="D0271" id="chk1_06"><label for="chk1_06">평교</label>
# 				<input type="checkbox" name="pIsuGb" value="D0261" id="chk1_07"><label for="chk1_07">복필</label>
# 				<input type="checkbox" name="pIsuGb" value="D0262" id="chk1_08"><label for="chk1_08">복선</label>
# 				<input type="checkbox" name="pIsuGb" value="D0251" id="chk1_09"><label for="chk1_09">부필</label>
# 				<input type="checkbox" name="pIsuGb" value="D0252" id="chk1_10"><label for="chk1_10">부선</label>
# 			</div>
# 			<div>
# 				<label class="is-label">학점</label>
# 				<input type="checkbox" name="pPnt" value="0" id="chk2_00"><label for="chk2_00">0</label>
# 				<input type="checkbox" name="pPnt" value="1" id="chk2_01"><label for="chk2_01">1</label>
# 				<input type="checkbox" name="pPnt" value="2" id="chk2_02"><label for="chk2_02">2</label>
# 				<input type="checkbox" name="pPnt" value="3" id="chk2_03"><label for="chk2_03">3</label>
# 				<input type="checkbox" name="pPnt" value="4" id="chk2_04"><label for="chk2_04">4</label>
# 				<input type="checkbox" name="pPnt" value="5" id="chk2_05"><label for="chk2_05">5</label>
# 				<input type="checkbox" name="pPnt" value="6" id="chk2_06"><label for="chk2_06">6</label>
# 			</div>
# 			<div>
# 				<label class="is-label">요일</label>
# 				<input type="checkbox" name="pDay" value="2" id="chk3_01"><label for="chk3_01">월</label>
# 				<input type="checkbox" name="pDay" value="3" id="chk3_02"><label for="chk3_02">화</label>
# 				<input type="checkbox" name="pDay" value="4" id="chk3_03"><label for="chk3_03">수</label>
# 				<input type="checkbox" name="pDay" value="5" id="chk3_04"><label for="chk3_04">목</label>
# 				<input type="checkbox" name="pDay" value="6" id="chk3_05"><label for="chk3_05">금</label>
# 				<input type="checkbox" name="pDay" value="7" id="chk3_06"><label for="chk3_06">토</label>
# 			</div>
# 			<div>
# 				<label class="is-label">영역</label>
# 				<input type="checkbox" name="pArea" value="5" id="chk4_01"><label for="chk4_01">교양인문</label>
# 				<input type="checkbox" name="pArea" value="7" id="chk4_02"><label for="chk4_02">교선자연</label>
# 				<input type="checkbox" name="pArea" value="4" id="chk4_03"><label for="chk4_03">교선사회</label>
# 				<input type="checkbox" name="pArea" value="19" id="chk4_04"><label for="chk4_04">해외교환</label>
# 				<input type="checkbox" name="pArea" value="20" id="chk4_05"><label for="chk4_05">해외창영역</label>
# 				<input type="checkbox" name="pArea" value="14" id="chk4_08"><label for="chk4_08">문화기획</label>
# 				<input type="checkbox" name="pArea" value="15" id="chk4_09"><label for="chk4_09">NGO 연계전공</label>
# 			</div>
#
#
# 			<div>
# 				<label class="is-label">역량</label>
# 				<p>가치역량 【
# 				<input type="checkbox" name="pAbility" value="10" id="chk5_01"><label for="chk5_01">인간인권</label>
# 				<input type="checkbox" name="pAbility" value="20" id="chk5_02"><label for="chk5_02">생명평화</label>
# 				<input type="checkbox" name="pAbility" value="30" id="chk5_03"><label for="chk5_03">민주시민</label> 】</p>
# 				<p>대안역량 【
# 				<input type="checkbox" name="pAbility" value="60" id="chk5_04"><label for="chk5_04">융복합적사고</label>
# 				<input type="checkbox" name="pAbility" value="70" id="chk5_05"><label for="chk5_05">조사분석정보활용</label>
# 				<input type="checkbox" name="pAbility" value="80" id="chk5_06"><label for="chk5_06">대안제시문제해결</label> 】</p>
# 				<p>실천역량 【
# 				<input type="checkbox" name="pAbility" value="40" id="chk5_07"><label for="chk5_07">민주적소통</label>
# 				<input type="checkbox" name="pAbility" value="50" id="chk5_08"><label for="chk5_08">연대와공동제적실천</label> 】</p>
# 			</div>
#
#
#
# 		</div>
# 		<div class="is-btn">
# 			<button id="btnReset" onclick="javascript:fnReset()">초기화</button>
# 			<button id="btnSearch" class="btn-sub">조회</button>
# 		</div>
# 	</div>
# 	<div id="warMsg" style="text-align:center;font-weight:bold;color:red"></div>
# 	</form>
# 	<!-- <p class="info-txt">조회시각 : <span id="timestamp"></span></p> -->
# 	<div class="sw-header mt-20">
# 		<h1>개설과목 내역 <small>【 <span style="color: #f76700;" id="CNT_LEC">0</span>건 】</small></h1><span class="info-txt">조회시각 : <span id="timestamp">2023-02-06 16:58:13:204</span></span>
# 	</div>
# 	<div class="wrap-content">
# 		<div class="wrap-grid"><div class="ui-jqgrid ui-widget ui-widget-content ui-corner-all" id="gbox_GridLecture" dir="ltr" style="width: 795px;"><div class="ui-widget-overlay jqgrid-overlay" id="lui_GridLecture"></div><div class="loading ui-state-default ui-state-active" id="load_GridLecture" style="display: none;">Loading ...</div><div class="ui-jqgrid-view" role="grid" id="gview_GridLecture" style="width: 795px;"><div class="ui-jqgrid-titlebar ui-jqgrid-caption ui-widget-header ui-corner-top ui-helper-clearfix" style="display: none;"><a role="link" class="ui-jqgrid-titlebar-close ui-corner-all HeaderButton" style="right: 0px;"><span class="ui-icon ui-icon-circle-triangle-n"></span></a><span class="ui-jqgrid-title"></span></div><div class="ui-state-default ui-jqgrid-hdiv ui-corner-top" style="width: 795px;"><div class="ui-jqgrid-hbox"><table class="ui-jqgrid-htable ui-common-table" style="width: 795px;" role="presentation" aria-labelledby="gbox_GridLecture"><thead><tr class="ui-jqgrid-labels" role="row"><th id="GridLecture_mode" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 75px;"><div id="jqgh_GridLecture_mode" class="ui-jqgrid-sortable">신청<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridLecture_lec_info" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 199px;"><div id="jqgh_GridLecture_lec_info" class="ui-jqgrid-sortable">과목정보<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridLecture_map_mj" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 125px;"><div id="jqgh_GridLecture_map_mj" class="ui-jqgrid-sortable">전공/이수구분<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridLecture_pnt" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 37px;"><div id="jqgh_GridLecture_pnt" class="ui-jqgrid-sortable">학점<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridLecture_pesn_nm" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 75px;"><div id="jqgh_GridLecture_pesn_nm" class="ui-jqgrid-sortable">대표교수<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridLecture_tita" role="columnheader" class="ui-state-default ui-th-column ui-th-ltr" style="width: 125px;"><div id="jqgh_GridLecture_tita" class="ui-jqgrid-sortable">강의시간<span class="s-ico" style="display:none"><span sort="asc" class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr"></span><span sort="desc" class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr"></span></span></div></th><th id="GridLecture_inwon" role="columnheader" class="ui-state-default ui-th-column ui-th ...
# 	</div>
#
# 	</div> <!-- tab_02 end -->
# </div><!-- end tab -->
# <div class="mt-20">&nbsp;</div>
# <form name="planForm" id="planForm" method="post">
# <input type="hidden" name="p01">
# <input type="hidden" name="p02">
# <input type="hidden" name="p03">
# <input type="hidden" name="p04">
# <input type="hidden" name="program" value="ul0303013">
# </form>
# <script src="/resources/js/fn-sugang.js?fake=1675670303517" type="text/javascript"></script>
# <script type="text/javascript">
# $(document).ready(function(){
# 	fnGridSugang();/* alert("chk = " + ); */
# 	fnGridBasket();
# 	fnInitGrid();
# 	$(".sw-tabs").each(function() {
# 		var $tab = $(this).find(" > li"),$tabBody = $(this).next(".sw-tab-contents");
# 		$tab.click(function(e){
# 			try{extendTimer();}catch(err){true;}
# 			$(".divide-control").removeClass("is-down");
# 			$(".sw-tab-contents").removeClass("hidden");
# 			if (!$(this).hasClass("is-active")) {
# 				var tabId = $(this).data("id");
# 				if(tabId == 'tab_01'){
# 					if($("#GridBasket").jqGrid("getGridParam", "datatype") == undefined){
# 						//fnGridBasket();
# 						setGridWidth("GridBasket");
# 					}else{
# 						$("#GridBasket").trigger("reloadGrid");
# 					}
# 				}else if(tabId == 'tab_02'){
# 					if($("#GridLecture").jqGrid("getGridParam", "datatype") == undefined){
# 						fnGridLecture();
# 					}else{
# 						//setGridSize("GridLecture");
# 						setGridWidth("GridLecture");
# 					}
# 				}
# 				$(this).addClass("is-active").siblings().removeClass("is-active");
# 		        $("#"+$(this).data("id")).addClass("is-active").siblings().removeClass("is-active");
# 		    }
# 		});
# 	});
# 	$('#pSearchNm').keypress(function(event){
# 		var keycode = (event.keyCode ? event.keyCode : event.which);
# 		if(keycode == 13){
# 			event.preventDefault();
# 			fnSearch();
# 		}
# 	});
# 	$('#btnSearch').off('click').on('click',function(){
# 		let $btn=$(this);
# 		if ($btn.hasClass('clicked')){
# 			return;
# 		}else{
# 			$btn.addClass('clicked');
# 			fnSearch();
# 			setTimeout(function() {
# 	        	$btn.removeClass('clicked');
# 			},500);
# 		}
# 	});
# 	$('#btnReset').off('click').on('click',function(){
# 		fnReset();
# 	});
# });
# function fnReset() {
# 	$("#pSosocCd").val("").prop("selected","selected");
# 	$("#pSearchNm").val("");
# 	$("input:checkbox[name='pIsuGb']").attr("checked", false);
# 	$("input:checkbox[name='pPnt']").attr("checked", false);
# 	$("input:checkbox[name='pDay']").attr("checked", false);
# 	$("input:checkbox[name='pArea']").attr("checked", false);
# 	$("input:checkbox[name='pAbility']").attr("checked", false);
# }
# function fnSearch(){
# 	$("#warMsg").html("");
# 	if($("#pSosocCd").val() == "" &&
# 	   $("#pSearchNm").val() == "" &&
# 	   $("input:checkbox[name='pIsuGb']:checked").length == 0 &&
# 	   $("input:checkbox[name='pPnt']:checked").length == 0 &&
# 	   $("input:checkbox[name='pDay']:checked").length == 0 &&
# 	   $("input:checkbox[name='pArea']:checked").length == 0 &&
# 	   $("input:checkbox[name='pAbility']:checked").length == 0){
# 		//Alert("1개 이상의 조건을 설정해 주세요.");
# 		$("#warMsg").html("1개 이상의 조건을 설정해 주세요.");
# 		return;
# 	}
# 	fnGridLecture();
# }
# function fnCredit(grid){
# 	var ids = grid.getDataIDs();
# 	var pntTot = '142';
# 	var pntPre = '0';
# 	var pntSum = 0;
# 	var PNT_TOT =0;
# 	$.each(ids,function(idx, rowId){
#         var rowData = grid.getRowData(rowId);
#      	pntSum += parseFloat(rowData.pnt);
#     });
# 	PNT_TOT = parseFloat(pntTot) + parseFloat(pntPre) + parseFloat(pntSum);
# 	$("#PNT_SUM").html(pntSum);
#  	$("#PNT_TOT").html("("+parseFloat(pntTot)+" + "+parseFloat(pntPre)+" + "+parseFloat(pntSum)+") = " + PNT_TOT);
# 	$("#CNT").html(ids.length);
# }
# function fnPlan(row){
# 	var frmData = document.planForm ;
# 	frmData.p01.value = row.year;
#     frmData.p02.value = row.smst_gbcd;
#     frmData.p03.value = row.course_cd;
#     frmData.p04.value = row.clas;
#     window.open("", 'popupView') ;
#      var url = "https://tis.skhu.ac.kr/api/open/program";
#      frmData.target = 'popupView';
#      frmData.method = "post";
#      frmData.action = url;
#      frmData.submit();
# }
# </script>
# </div></main>
#
# 	</body></html>

# %%
soup = bs(driver.page_source, 'lxml')
soup
# Out:
# <html lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="user-scalable=no, initial-scale=1, maximum-scale=1, minimum-scale=1, width=device-width, viewport-fit=cover" name="viewport"/>
# <meta content="date=no" name="format-detection"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <title>성공회대학교 수강신청시스템</title>
# <link href="/resources/css/ui.css" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/jqgrid.css" rel="stylesheet" type="text/css"/>
# <style>
# /* @media (min-width: 1000px)
# body.main>header .is-right .user-info {
#     width: 320px;
# }
# @media (min-width: 1000px)
# body.main>header .is-right .user-info button {
#     margin: auto;
# } */
# @media (min-width: 1000px)
# body.main>header .is-right .user-info button {
#     margin-top: 0px;
# }
# </style>
# <link href="/resources/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/resources/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <script src="/resources/js/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/resources/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/resources/js/jquery.jqGrid.min.js" type="text/javascript"></script>
# <script src="/resources/js/confirm.js" type="text/javascript"></script>
# <script src="/resources/js/project-ui.js?v=" type="text/javascript"></script>
# <script src="/resources/js/app-message.js" type="text/javascript"></script>
# <script type="text/javascript">
# var context = "";
# $(function() {
#
# 	//메뉴 제어
# 	$(".nav-menu  > li > span").each(function(){
# 		var $sub = $(this).next("div");
# 		$(this).click(function(){
# 			if($(this).hasClass("is-active")){
# 				$(this).removeClass("is-active");
# 				$sub.slideUp("fast");
# 			}
# 			else{
# 				$(".nav-menu  > li > span").removeClass("is-active");
# 				$(".nav-menu  > li > div").hide();//.slideUp("fast");
# 				$(this).addClass("is-active");
# 				$sub.slideDown("fast");
# 			}
# 		});
# 	});
# 	$(".m-menu").click(function(){
# 		$(".wrap-header .is-right").slideToggle();
# 	});
# 	$(window).bind('resize', function() {
# 		if($(".m-menu").css("display") == "block"){
# 			$(".wrap-header .is-right").hide();
# 		}else{
# 			$(".wrap-header .is-right").show();
# 		}
# 	});
# 	$(document).click(function(e) {
# 		if($(".m-menu").css("display") == "block"){
# 			if ($(e.target).closest(".m-menu, .wrap-header .is-right").length === 0) {
# 				$(".wrap-header .is-right").hide();
# 			}
# 		}
# 		 if($(".nav-menu > li > span").hasClass("is-active")){
# 			if($(e.target).closest(".nav-menu").length === 0){
# 				$(".nav-menu  > li > span").removeClass("is-active");
# 				$(".nav-menu  > li > div").hide();
# 			}
# 		}
# 	});
#
# 	//Top 버튼
# 	$('.to-top').click(function(){
# 		$("html, body").animate({scrollTop : 0},500);
# 		return false;
# 	});
# 	$(window).scroll(function() {
# 		//Top 버튼
# 		if ($(this).scrollTop() > 100) {
# 			$('.to-top').fadeIn("fast");
# 		} else {
# 			$('.to-top').fadeOut("fast");
# 		}
# 	});
# 	const menu = JSON.parse(localStorage.getItem('menu'));
# 	let menuUrl;
# 	if(menu == null){
# 		menuUrl	= "/core/schedule";
# 	}else{
# 		menuUrl = menu.menuUrl;
# 	}
# 	fnMenuLoad(menuUrl);
# 	try{
# 		if(parent.fnAppUsed() == false){
# 			top.location.href = "about:blank";
# 		}
# 	}catch(err){
# 		top.location.href = "about:blank";
# 	}
# });
# function logout(msg){
# 	if(msg == undefined){
# 		fnLogout(fnGetMessage(2), goLogout, '', true);
# 	}else{
# 		fnLogout(msg, goLogout);
# 	}
# }
# function goLogout(){
# 	localStorage.clear();
# 	location.href= context + "/logOut?fake=" + Date.now();
# }
# function fnMenuLoad(menuUrl){
# 	try{extendTimer();}catch(err){}
# 	localStorage.setItem('menu',JSON.stringify({'menuUrl': menuUrl}));
# 	$(".nav-menu  > li > span").removeClass("is-active");
# 	$(".nav-menu  > li > div").hide();
# 	if($(".m-menu").css("display") == "block"){
# 		$(".wrap-header .is-right").hide();
# 	}
# 	$(".s-contents > div").empty();
# 	let queryStr = (menuUrl.indexOf("?")>-1 ? "&":"?") + "fake="+Date.now();
# 	$(".s-contents > div").load(context + menuUrl + queryStr, function(response, status, xhr) {
# 		if(status == "success"){
# 			var rs, code, msg;
# 			try{
# 				rs = $.parseJSON(response);
# 			}catch(err){}
# 			if(rs == undefined){
# 				code = "200";
# 				msg  = "OK";
# 			}else{
# 				code = rs.code || rs.rows[0].code;
# 				msg = rs.msg || rs.rows[0].msg;
# 			}
# 			if(code == "999"){
# 				$(".s-contents > div").hide();
# 				logout(msg);
# 			}else if(code == "DB" || code != "200"){
# 				$(".s-contents > div").empty();
# 				fnAlert(msg);
# 			}
# 		}else{
# 			var chk = function(){
# 				setTimeout(function(){
# 					location.reload();
# 				},500);
# 			}
# 		}
# 	});
# }
# function gridCheck(data, grid){
# 	 try{
# 		var code = data.code || data.rows[0].code;
# 		var msg = data.msg || data.rows[0].msg;
# 		if(code == "999"){
# 			logout(msg);
# 			return false;
# 		}else if(code == "500"){
# 			setNodata(grid, msg);
# 			return false;
# 		}
# 	}catch(err){
# 		return true;
# 	}
# 	return true;
# }
# function fnHome(){
# 	localStorage.clear();
# 	parent.location.href = context + "/";
# }
# </script>
# <style>
# .main-menu{cursor:pointer;}
# .tbl-detail, .wrap-grid{min-width:600px;}
# </style>
# </head>
# <body class="main">
# <div class="wrap-loader hidden" style="display: none;"><span class="loading-helper"></span><div class="loader"></div><div class="loading-text">Loading</div></div>
# <span class="to-top" style="display: inline-block;"></span>
# <header>
# <div class="wrap-header">
# <div class="is-left" onclick="fnHome()" style="cursor:pointer;" title="홈(Home)">
# <span>수강신청</span>
# </div>
# <div class="is-right" style="display: none;">
# <ul class="nav-menu">
# <li>
# <span class="main-menu">수강신청</span>
# <div style="display: none;">
# <ul>
# <li onclick="fnMenuLoad('/core/coreNotice1')">신청</li>
# <li onclick="fnMenuLoad('/sugang/sugangSelect')">결과조회</li>
# </ul>
# </div>
# </li>
# <li>
# <span class="main-menu">수강바구니</span>
# <div style="display: none;">
# <ul>
# <li onclick="fnMenuLoad('/core/coreNotice2')">신청</li>
# <li onclick="fnMenuLoad('/basket/basketSelect')">결과조회</li>
# </ul>
# </div>
# </li>
# <li>
# <span class="main-menu">제한수업</span>
# <div style="display: none;">
# <ul>
# <li onclick="fnMenuLoad('/core/coreNotice3')">신청</li>
# <li onclick="fnMenuLoad('/sugang/limitSelect')">결과조회</li>
# </ul>
# </div>
# </li>
# <li>
# <span class="main-menu">대체과목 재수강</span>
# <div style="display: none;">
# <ul>
# <li onclick="fnMenuLoad('/core/coreValid?pScheGb=0214')">신청</li>
# <!-- <li onclick="fnMenuLoad('/core/coreNotice5')">신청</li> -->
# </ul>
# </div>
# </li>
# <li>
# <span class="main-menu">수강철회</span>
# <div style="display: none;">
# <ul>
# <li onclick="fnMenuLoad('/core/coreNotice4')">신청</li>
# <li onclick="fnMenuLoad('/sugang/withdrawSelect')">결과조회</li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="user-info">
# <div><span class="is-id">201814102</span><span>박결</span><br/>
# <span>공학계 IT융합자율학부</span>
# <span>4학년</span>
# </div>
# <button class="btn-sub" id="btn" onclick="logout()" type="button">로그아웃</button>
# </div>
# </div>
# <div class="m-menu"></div>
# </div>
# </header>
# <main class="s-contents" id="s-contents"><div>
# <h1 class="is-title">2023년 1학기 재학생 수강신청</h1>
# <div class="sw-header">
# <h1>기본정보</h1>
# </div>
# <div class="wrap-content">
# <table class="tbl-detail">
# <colgroup>
# <col width="90px"/>
# <col/>
# <col width="90px"/>
# <col/>
# <col width="90px"/>
# <col/>
# </colgroup>
# <tbody>
# <tr>
# <th>학번</th>
# <td>201814102</td>
# <th>성명</th>
# <td>박결</td>
# <th>학적상태</th>
# <td>재학</td>
# </tr>
# <tr>
# <th>소속</th>
# <td>IT융합자율학부</td>
# <th>학년이수학기</th>
# <td>4학년(9학기)</td>
# <th>과정구분</th>
# <td>학부과정</td>
# </tr>
# <tr>
# <th>신청전공</th>
# <td colspan="5">IT융합자율학부<br/>(주전공) 소프트웨어공학전공<br/>(부전공) 컴퓨터공학전공</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="sw-header mt-20">
# <h1>학점정보</h1>
# </div>
# <div class="wrap-content">
# <table class="tbl-detail">
# <colgroup>
# <col width="10%"/>
# <col width="10%"/>
# <col width="10%"/>
# <col width="20%"/>
# <col width="10%"/>
# <col width="20%"/>
# </colgroup>
# <thead>
# <tr>
# <th>직전학기 평점/취득</th>
# <th>학점세이브</th>
# <th>선신청 학점</th>
# <th>신청가능 학점</th>
# <th>신청학점</th>
# <th>수강 예정 학점</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="alignC">2.33 / 142</td>
# <td class="alignC">0</td>
# <td class="alignC">0</td>
# <td class="alignC"><span style="font-size:11px">(기본 + 성적우수 +<br/>
# 									학점세이브 - 선신청)=신청가능</span><br/>
# <b>(19 + 0 + 0 - 0) = 19</b></td>
# <td class="alignC"><span id="PNT_SUM">3</span></td>
# <td class="alignC"><span style="font-size:11px">(기존 총취득 학점 + 선신청학점 +<br/>
# 									신청학점)=총 취득 예상 학점</span><br/>
# <b id="PNT_TOT">(142 + 0 + 3) = 145</b></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="sw-header mt-20">
# <h1>수강신청 내역 <small>【 신청과목수 : <span id="CNT" style="color: #f76700;">1</span>건 】</small></h1>
# </div>
# <div class="wrap-content">
# <div class="wrap-grid"><div class="ui-jqgrid ui-widget ui-widget-content ui-corner-all" dir="ltr" id="gbox_GridSugang" style="width: 795px;"><div class="ui-widget-overlay jqgrid-overlay" id="lui_GridSugang"></div><div class="loading ui-state-default ui-state-active" id="load_GridSugang" style="display: none;">Loading ...</div><div class="ui-jqgrid-view" id="gview_GridSugang" role="grid" style="width: 795px;"><div class="ui-jqgrid-titlebar ui-jqgrid-caption ui-widget-header ui-corner-top ui-helper-clearfix" style="display: none;"><a class="ui-jqgrid-titlebar-close ui-corner-all HeaderButton" role="link" style="right: 0px;"><span class="ui-icon ui-icon-circle-triangle-n"></span></a><span class="ui-jqgrid-title"></span></div><div class="ui-state-default ui-jqgrid-hdiv ui-corner-top" style="width: 795px;"><div class="ui-jqgrid-hbox"><table aria-labelledby="gbox_GridSugang" class="ui-jqgrid-htable ui-common-table" role="presentation" style="width: 795px;"><thead><tr class="ui-jqgrid-labels" role="row"><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_mode" role="columnheader" style="width: 62px;"><div class="ui-jqgrid-sortable" id="jqgh_GridSugang_mode">삭제<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_lec_info" role="columnheader" style="width: 164px;"><div class="ui-jqgrid-sortable" id="jqgh_GridSugang_lec_info">과목정보<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_map_mj" role="columnheader" style="width: 103px;"><div class="ui-jqgrid-sortable" id="jqgh_GridSugang_map_mj">전공/이수구분<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_pnt" role="columnheader" style="width: 31px;"><div class="ui-jqgrid-sortable" id="jqgh_GridSugang_pnt">학점<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_pesn_nm" role="columnheader" style="width: 62px;"><div class="ui-jqgrid-sortable" id="jqgh_GridSugang_pesn_nm">대표교수<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_ability" role="columnheader" style="width: 62px;"><div class="ui-jqgrid-sortable" id="jqgh_GridSugang_ability">핵심역량<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridSugang_ability_detail" role="columnheader"  ...
# </div>
# <ul class="sw-tabs mt-20" id="sTabs">
# <li class="is-active" data-id="tab_01">수강바구니 조회/신청</li>
# <li data-id="tab_02">개설과목 조회/신청</li>
# </ul>
# <div class="sw-tab-contents" id="tab">
# <div class="is-active" id="tab_01">
# <div class="wrap-content">
# <div class="wrap-grid"><div class="ui-jqgrid ui-widget ui-widget-content ui-corner-all" dir="ltr" id="gbox_GridBasket" style="width: 795px;"><div class="ui-widget-overlay jqgrid-overlay" id="lui_GridBasket"></div><div class="loading ui-state-default ui-state-active" id="load_GridBasket" style="display: none;">Loading ...</div><div class="ui-jqgrid-view" id="gview_GridBasket" role="grid" style="width: 795px;"><div class="ui-jqgrid-titlebar ui-jqgrid-caption ui-widget-header ui-corner-top ui-helper-clearfix" style="display: none;"><a class="ui-jqgrid-titlebar-close ui-corner-all HeaderButton" role="link" style="right: 0px;"><span class="ui-icon ui-icon-circle-triangle-n"></span></a><span class="ui-jqgrid-title"></span></div><div class="ui-state-default ui-jqgrid-hdiv ui-corner-top" style="width: 795px;"><div class="ui-jqgrid-hbox"><table aria-labelledby="gbox_GridBasket" class="ui-jqgrid-htable ui-common-table" role="presentation" style="width: 795px;"><thead><tr class="ui-jqgrid-labels" role="row"><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_mode" role="columnheader" style="width: 62px;"><div class="ui-jqgrid-sortable" id="jqgh_GridBasket_mode">신청<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_lec_info" role="columnheader" style="width: 164px;"><div class="ui-jqgrid-sortable" id="jqgh_GridBasket_lec_info">과목정보<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_map_mj" role="columnheader" style="width: 103px;"><div class="ui-jqgrid-sortable" id="jqgh_GridBasket_map_mj">전공/이수구분<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_pnt" role="columnheader" style="width: 31px;"><div class="ui-jqgrid-sortable" id="jqgh_GridBasket_pnt">학점<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_pesn_nm" role="columnheader" style="width: 62px;"><div class="ui-jqgrid-sortable" id="jqgh_GridBasket_pesn_nm">대표교수<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_ability" role="columnheader" style="width: 62px;"><div class="ui-jqgrid-sortable" id="jqgh_GridBasket_ability">핵심역량<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridBasket_ability_detail" role="columnheader"  ...
# </div>
# </div>
# <div id="tab_02">
# <div class="info-box">
# <p>① 조회조건을 1개이상 설정 후 조회 가능합니다.</p>
# <p>② 과목 옆에 표시되는 전공/이수구분은 성적취득 시 실제로 취득되는 전공정보와 이수구분이 나타납니다.</p>
# <p>③ 전필, 전선, 전탐의 경우 본인의 신청전공 및 수업학년에 해당하는 과목만 조회가능합니다.</p>
# </div>
# <form id="sForm" method="post" name="sForm" onsubmit="return false">
# <div class="form-search">
# <div>
# <div>
# <select id="pSosocCd" name="pSosocCd">
# <option value="">전체</option>
# <option value="U080000">학부 열림교양대학</option>
# <option value="UCE0000">혁신융합계열 국제문화전공</option>
# <option value="UD00000">사회계 미디어콘텐츠융합자율학부</option>
# <option value="UDA0000">미디어콘텐츠융합자율학부 디지털콘텐츠전공</option>
# <option value="UDB0000">미디어콘텐츠융합자율학부 신문방송학전공</option>
# <option value="UH00000">인문계 인문융합자율학부</option>
# <option value="UHB0000">인문융합자율학부 기독교문화전공</option>
# <option value="UHC0000">인문융합자율학부 영어학전공</option>
# <option value="UHD0000">인문융합자율학부 일어일본학전공</option>
# <option value="UHE0000">인문융합자율학부 중어중국학전공</option>
# <option value="UI00000">공학계 IT융합자율학부</option>
# <option value="UIB0000">IT융합자율학부 컴퓨터공학전공</option>
# <option value="UIC0000">IT융합자율학부 소프트웨어공학전공</option>
# <option value="UID0000">IT융합자율학부 정보통신공학전공</option>
# <option value="UIF0000">IT융합자율학부 인공지능전공</option>
# <option value="US00000">사회계 사회융합자율학부</option>
# <option value="USB0000">사회융합자율학부 사회복지학전공</option>
# <option value="USC0000">사회융합자율학부 사회학전공</option>
# <option value="USD0000">사회융합자율학부 경제학전공</option>
# <option value="USE0000">사회융합자율학부 정치학전공</option>
# <option value="USH0000">사회융합자율학부 경영학전공</option>
# </select>
# <label class="is-label">과목명/과목코드/교원명</label>
# <input id="pSearchNm" maxlength="30" name="pSearchNm" type="text"/>
# </div>
# <div class="is-full">
# <label class="is-label">이수구분</label>
# <input id="chk1_01" name="pIsuGb" type="checkbox" value="D0221"/><label for="chk1_01">전필</label>
# <input id="chk1_02" name="pIsuGb" type="checkbox" value="D0222"/><label for="chk1_02">전선</label>
# <input id="chk1_03" name="pIsuGb" type="checkbox" value="D0223"/><label for="chk1_03">전탐</label>
# <input id="chk1_04" name="pIsuGb" type="checkbox" value="D0210"/><label for="chk1_04">교필</label>
# <input id="chk1_05" name="pIsuGb" type="checkbox" value="D0213"/><label for="chk1_05">교선</label>
# <input id="chk1_06" name="pIsuGb" type="checkbox" value="D0271"/><label for="chk1_06">평교</label>
# <input id="chk1_07" name="pIsuGb" type="checkbox" value="D0261"/><label for="chk1_07">복필</label>
# <input id="chk1_08" name="pIsuGb" type="checkbox" value="D0262"/><label for="chk1_08">복선</label>
# <input id="chk1_09" name="pIsuGb" type="checkbox" value="D0251"/><label for="chk1_09">부필</label>
# <input id="chk1_10" name="pIsuGb" type="checkbox" value="D0252"/><label for="chk1_10">부선</label>
# </div>
# <div>
# <label class="is-label">학점</label>
# <input id="chk2_00" name="pPnt" type="checkbox" value="0"/><label for="chk2_00">0</label>
# <input id="chk2_01" name="pPnt" type="checkbox" value="1"/><label for="chk2_01">1</label>
# <input id="chk2_02" name="pPnt" type="checkbox" value="2"/><label for="chk2_02">2</label>
# <input id="chk2_03" name="pPnt" type="checkbox" value="3"/><label for="chk2_03">3</label>
# <input id="chk2_04" name="pPnt" type="checkbox" value="4"/><label for="chk2_04">4</label>
# <input id="chk2_05" name="pPnt" type="checkbox" value="5"/><label for="chk2_05">5</label>
# <input id="chk2_06" name="pPnt" type="checkbox" value="6"/><label for="chk2_06">6</label>
# </div>
# <div>
# <label class="is-label">요일</label>
# <input id="chk3_01" name="pDay" type="checkbox" value="2"/><label for="chk3_01">월</label>
# <input id="chk3_02" name="pDay" type="checkbox" value="3"/><label for="chk3_02">화</label>
# <input id="chk3_03" name="pDay" type="checkbox" value="4"/><label for="chk3_03">수</label>
# <input id="chk3_04" name="pDay" type="checkbox" value="5"/><label for="chk3_04">목</label>
# <input id="chk3_05" name="pDay" type="checkbox" value="6"/><label for="chk3_05">금</label>
# <input id="chk3_06" name="pDay" type="checkbox" value="7"/><label for="chk3_06">토</label>
# </div>
# <div>
# <label class="is-label">영역</label>
# <input id="chk4_01" name="pArea" type="checkbox" value="5"/><label for="chk4_01">교양인문</label>
# <input id="chk4_02" name="pArea" type="checkbox" value="7"/><label for="chk4_02">교선자연</label>
# <input id="chk4_03" name="pArea" type="checkbox" value="4"/><label for="chk4_03">교선사회</label>
# <input id="chk4_04" name="pArea" type="checkbox" value="19"/><label for="chk4_04">해외교환</label>
# <input id="chk4_05" name="pArea" type="checkbox" value="20"/><label for="chk4_05">해외창영역</label>
# <input id="chk4_08" name="pArea" type="checkbox" value="14"/><label for="chk4_08">문화기획</label>
# <input id="chk4_09" name="pArea" type="checkbox" value="15"/><label for="chk4_09">NGO 연계전공</label>
# </div>
# <div>
# <label class="is-label">역량</label>
# <p>가치역량 【
# 				<input id="chk5_01" name="pAbility" type="checkbox" value="10"/><label for="chk5_01">인간인권</label>
# <input id="chk5_02" name="pAbility" type="checkbox" value="20"/><label for="chk5_02">생명평화</label>
# <input id="chk5_03" name="pAbility" type="checkbox" value="30"/><label for="chk5_03">민주시민</label> 】</p>
# <p>대안역량 【
# 				<input id="chk5_04" name="pAbility" type="checkbox" value="60"/><label for="chk5_04">융복합적사고</label>
# <input id="chk5_05" name="pAbility" type="checkbox" value="70"/><label for="chk5_05">조사분석정보활용</label>
# <input id="chk5_06" name="pAbility" type="checkbox" value="80"/><label for="chk5_06">대안제시문제해결</label> 】</p>
# <p>실천역량 【
# 				<input id="chk5_07" name="pAbility" type="checkbox" value="40"/><label for="chk5_07">민주적소통</label>
# <input id="chk5_08" name="pAbility" type="checkbox" value="50"/><label for="chk5_08">연대와공동제적실천</label> 】</p>
# </div>
# </div>
# <div class="is-btn">
# <button id="btnReset" onclick="javascript:fnReset()">초기화</button>
# <button class="btn-sub" id="btnSearch">조회</button>
# </div>
# </div>
# <div id="warMsg" style="text-align:center;font-weight:bold;color:red"></div>
# </form>
# <!-- <p class="info-txt">조회시각 : <span id="timestamp"></span></p> -->
# <div class="sw-header mt-20">
# <h1>개설과목 내역 <small>【 <span id="CNT_LEC" style="color: #f76700;">0</span>건 】</small></h1><span class="info-txt">조회시각 : <span id="timestamp">2023-02-06 16:58:13:204</span></span>
# </div>
# <div class="wrap-content">
# <div class="wrap-grid"><div class="ui-jqgrid ui-widget ui-widget-content ui-corner-all" dir="ltr" id="gbox_GridLecture" style="width: 795px;"><div class="ui-widget-overlay jqgrid-overlay" id="lui_GridLecture"></div><div class="loading ui-state-default ui-state-active" id="load_GridLecture" style="display: none;">Loading ...</div><div class="ui-jqgrid-view" id="gview_GridLecture" role="grid" style="width: 795px;"><div class="ui-jqgrid-titlebar ui-jqgrid-caption ui-widget-header ui-corner-top ui-helper-clearfix" style="display: none;"><a class="ui-jqgrid-titlebar-close ui-corner-all HeaderButton" role="link" style="right: 0px;"><span class="ui-icon ui-icon-circle-triangle-n"></span></a><span class="ui-jqgrid-title"></span></div><div class="ui-state-default ui-jqgrid-hdiv ui-corner-top" style="width: 795px;"><div class="ui-jqgrid-hbox"><table aria-labelledby="gbox_GridLecture" class="ui-jqgrid-htable ui-common-table" role="presentation" style="width: 795px;"><thead><tr class="ui-jqgrid-labels" role="row"><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_mode" role="columnheader" style="width: 75px;"><div class="ui-jqgrid-sortable" id="jqgh_GridLecture_mode">신청<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_lec_info" role="columnheader" style="width: 199px;"><div class="ui-jqgrid-sortable" id="jqgh_GridLecture_lec_info">과목정보<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_map_mj" role="columnheader" style="width: 125px;"><div class="ui-jqgrid-sortable" id="jqgh_GridLecture_map_mj">전공/이수구분<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_pnt" role="columnheader" style="width: 37px;"><div class="ui-jqgrid-sortable" id="jqgh_GridLecture_pnt">학점<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_pesn_nm" role="columnheader" style="width: 75px;"><div class="ui-jqgrid-sortable" id="jqgh_GridLecture_pesn_nm">대표교수<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_tita" role="columnheader" style="width: 125px;"><div class="ui-jqgrid-sortable" id="jqgh_GridLecture_tita">강의시간<span class="s-ico" style="display:none"><span class="ui-grid-ico-sort ui-icon-asc ui-state-disabled ui-icon ui-icon-triangle-1-n ui-sort-ltr" sort="asc"></span><span class="ui-grid-ico-sort ui-icon-desc ui-state-disabled ui-icon ui-icon-triangle-1-s ui-sort-ltr" sort="desc"></span></span></div></th><th class="ui-state-default ui-th-column ui-th-ltr" id="GridLecture_inwon" role="columnhead ...
# </div>
# </div> <!-- tab_02 end -->
# </div><!-- end tab -->
# <div class="mt-20"> </div>
# <form id="planForm" method="post" name="planForm">
# <input name="p01" type="hidden"/>
# <input name="p02" type="hidden"/>
# <input name="p03" type="hidden"/>
# <input name="p04" type="hidden"/>
# <input name="program" type="hidden" value="ul0303013"/>
# </form>
# <script src="/resources/js/fn-sugang.js?fake=1675670303517" type="text/javascript"></script>
# <script type="text/javascript">
# $(document).ready(function(){
# 	fnGridSugang();/* alert("chk = " + ); */
# 	fnGridBasket();
# 	fnInitGrid();
# 	$(".sw-tabs").each(function() {
# 		var $tab = $(this).find(" > li"),$tabBody = $(this).next(".sw-tab-contents");
# 		$tab.click(function(e){
# 			try{extendTimer();}catch(err){true;}
# 			$(".divide-control").removeClass("is-down");
# 			$(".sw-tab-contents").removeClass("hidden");
# 			if (!$(this).hasClass("is-active")) {
# 				var tabId = $(this).data("id");
# 				if(tabId == 'tab_01'){
# 					if($("#GridBasket").jqGrid("getGridParam", "datatype") == undefined){
# 						//fnGridBasket();
# 						setGridWidth("GridBasket");
# 					}else{
# 						$("#GridBasket").trigger("reloadGrid");
# 					}
# 				}else if(tabId == 'tab_02'){
# 					if($("#GridLecture").jqGrid("getGridParam", "datatype") == undefined){
# 						fnGridLecture();
# 					}else{
# 						//setGridSize("GridLecture");
# 						setGridWidth("GridLecture");
# 					}
# 				}
# 				$(this).addClass("is-active").siblings().removeClass("is-active");
# 		        $("#"+$(this).data("id")).addClass("is-active").siblings().removeClass("is-active");
# 		    }
# 		});
# 	});
# 	$('#pSearchNm').keypress(function(event){
# 		var keycode = (event.keyCode ? event.keyCode : event.which);
# 		if(keycode == 13){
# 			event.preventDefault();
# 			fnSearch();
# 		}
# 	});
# 	$('#btnSearch').off('click').on('click',function(){
# 		let $btn=$(this);
# 		if ($btn.hasClass('clicked')){
# 			return;
# 		}else{
# 			$btn.addClass('clicked');
# 			fnSearch();
# 			setTimeout(function() {
# 	        	$btn.removeClass('clicked');
# 			},500);
# 		}
# 	});
# 	$('#btnReset').off('click').on('click',function(){
# 		fnReset();
# 	});
# });
# function fnReset() {
# 	$("#pSosocCd").val("").prop("selected","selected");
# 	$("#pSearchNm").val("");
# 	$("input:checkbox[name='pIsuGb']").attr("checked", false);
# 	$("input:checkbox[name='pPnt']").attr("checked", false);
# 	$("input:checkbox[name='pDay']").attr("checked", false);
# 	$("input:checkbox[name='pArea']").attr("checked", false);
# 	$("input:checkbox[name='pAbility']").attr("checked", false);
# }
# function fnSearch(){
# 	$("#warMsg").html("");
# 	if($("#pSosocCd").val() == "" &&
# 	   $("#pSearchNm").val() == "" &&
# 	   $("input:checkbox[name='pIsuGb']:checked").length == 0 &&
# 	   $("input:checkbox[name='pPnt']:checked").length == 0 &&
# 	   $("input:checkbox[name='pDay']:checked").length == 0 &&
# 	   $("input:checkbox[name='pArea']:checked").length == 0 &&
# 	   $("input:checkbox[name='pAbility']:checked").length == 0){
# 		//Alert("1개 이상의 조건을 설정해 주세요.");
# 		$("#warMsg").html("1개 이상의 조건을 설정해 주세요.");
# 		return;
# 	}
# 	fnGridLecture();
# }
# function fnCredit(grid){
# 	var ids = grid.getDataIDs();
# 	var pntTot = '142';
# 	var pntPre = '0';
# 	var pntSum = 0;
# 	var PNT_TOT =0;
# 	$.each(ids,function(idx, rowId){
#         var rowData = grid.getRowData(rowId);
#      	pntSum += parseFloat(rowData.pnt);
#     });
# 	PNT_TOT = parseFloat(pntTot) + parseFloat(pntPre) + parseFloat(pntSum);
# 	$("#PNT_SUM").html(pntSum);
#  	$("#PNT_TOT").html("("+parseFloat(pntTot)+" + "+parseFloat(pntPre)+" + "+parseFloat(pntSum)+") = " + PNT_TOT);
# 	$("#CNT").html(ids.length);
# }
# function fnPlan(row){
# 	var frmData = document.planForm ;
# 	frmData.p01.value = row.year;
#     frmData.p02.value = row.smst_gbcd;
#     frmData.p03.value = row.course_cd;
#     frmData.p04.value = row.clas;
#     window.open("", 'popupView') ;
#      var url = "https://tis.skhu.ac.kr/api/open/program";
#      frmData.target = 'popupView';
#      frmData.method = "post";
#      frmData.action = url;
#      frmData.submit();
# }
# </script>
# </div></main>
# </body></html>
